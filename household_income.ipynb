# %%
import pandas as pd
import numpy as np

# %%
import ssl

ssl._create_default_https_context = ssl._create_unverified_context

# %%
pgh_aggregate_income = pd.read_csv("https://data.wprdc.org/dataset/5b18c198-474c-4723-b735-cc5220ad43cc/resource/34842307-0da6-458a-9df3-a09ab3e3a489/download/aggregate-household-income-in-the-past-12-months-in-2015-inflation-adjusted-dollars.csv", 
                                 index_col = "Neighborhood", parse_dates = True)
pgh_aggregate_income.head(91)
# Out:
#                      Id  \
# Neighborhood
# Allegheny Center      1
# Allegheny West        2
# Allentown             3
# Arlington             4
# Arlington Heights     5
# ...                  ..
# Upper Lawrenceville  87
# West End             88
# West Oakland         89
# Westwood             90
# Windgap              91
#
#                     Estimate; Aggregate household income in the past 12 months (in 2015 Inflation-adjusted dollars)  \
# Neighborhood
# Allegheny Center                                              39947000
# Allegheny West                                                23793300
# Allentown                                                     38303700
# Arlington                                                     35349900
# Arlington Heights                                              2389600
# ...                                                                ...
# Upper Lawrenceville                                           65738500
# ...

# %%
try:
    pgh_aggregate_income = pgh_aggregate_income.drop(["Chateau", "South Shore"], axis = 0)
except:
    print()
convert_type = {"Estimate; Aggregate household income in the past 12 months (in 2015 Inflation-adjusted dollars)": float}
pgh_aggregate_income = pgh_aggregate_income.astype(convert_type)
pgh_aggregate_income.sort_values("Estimate; Aggregate household income in the past 12 months (in 2015 Inflation-adjusted dollars)", ascending = False).head(20)
# Out:
#                            Id  \
# Neighborhood
# Squirrel Hill South        78
# Shadyside                  69
# Squirrel Hill North        77
# Brookline                  14
# Point Breeze               64
# Mount Washington           54
# Bloomfield                 10
# Highland Park              40
# Greenfield                 37
# South Side Flats           73
# Carrick                    16
# Central Business District  17
# Brighton Heights           13
# Beechview                   8
# Central Lawrenceville      18
# Banksville                  6
# Stanton Heights            80
# South Side Slopes          74
# North Oakland              57
# East Liberty               29
#
#                            Estimate; Aggregate household income in the past 12 months (in 2015 Inflation-adjusted dollars)  \
# Neighborhood
# Squirrel Hill South                                              659886300.0
# Shadyside                                                        605635700.0
# ...
