# %%
import pandas as pd
import numpy as np

import ssl

ssl._create_default_https_context = ssl._create_unverified_context

# %%
# load the pata data directly from the WPRDC and parse id directly
parks = pd.read_csv("https://data.wprdc.org/datastore/dump/47350364-44a8-4d15-b6e0-5f79ddff9367",
                           index_col="id")
parks.head(12)
# Out:
#                                 name  type maintenance_responsibility  \
# id
# 731501774       Able Long Playground   NaN            Parks - Western
# 1461276747  Albert Graham Playground   NaN           Parks - Schenley
# 1860709784         Alpine Playground   NaN           Parks - Northern
# 1770671485          Alton Playground   NaN            Parks - Western
# 18942817            Ammon Playground   NaN           Parks - Schenley
# 230731204       Arlington Playground   NaN           Parks - Southern
# 420573029       Armstrong Playground   NaN           Parks - Southern
# 113170092         Arsenal Playground   NaN          Parks - Northeast
# 2089697067  August WIlson Playground   NaN           Parks - Schenley
# 2124405123     Banksville Playground   NaN            Parks - Western
# 202656658          Baxter Playground   NaN            Parks - Eastern
# 966305264         Bon Air Playground   NaN           Parks - Southern
#
# ...

# %%
freq_table = parks.neighborhood.value_counts()

# %%
freq_table #PRINT IT OUT
# Out:
# Squirrel Hill South      8
# Beechview                5
# South Side Slopes        5
# Sheraden                 4
# Allegheny Center         4
#                         ..
# Central Lawrenceville    1
# East Carnegie            1
# Spring Hill-City View    1
# Allentown                1
# Swisshelm Park           1
# Name: neighborhood, Length: 67, dtype: int64
