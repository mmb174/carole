# %%
import pandas as pd
import numpy as np

# %%
import ssl

ssl._create_default_https_context = ssl._create_unverified_context

# %%
pgh_aggregate_income = pd.read_csv("aggregate-household-income-in-the-past-12-months-in-2015-inflation-adjusted-dollars.csv", 
                                 index_col = "Id", parse_dates = True)
pgh_aggregate_income.head(89)
# Out:
#            Neighborhood  \
# Id
# 1      Allegheny Center
# 2        Allegheny West
# 3             Allentown
# 4             Arlington
# 5     Arlington Heights
# ..                  ...
# 87  Upper Lawrenceville
# 88             West End
# 89         West Oakland
# 90             Westwood
# 91              Windgap
#
#     Estimate; Aggregate household income in the past 12 months (in 2015 Inflation-adjusted dollars)  \
# Id
# 1                                            39947000
# 2                                            23793300
# 3                                            38303700
# 4                                            35349900
# 5                                             2389600
# ..                                                ...
# 87                                           65738500
# 88                                            3615800
# 89                                           16339500
# 90                                           91857100
# ...

# %%
convert_type = {"Estimate; Aggregate household income in the past 12 months (in 2015 Inflation-adjusted dollars)": float}
pgh_aggregate_income = pgh_aggregate_income.astype(convert_type)
pgh_aggregate_income.sort_values("Estimate; Aggregate household income in the past 12 months (in 2015 Inflation-adjusted dollars)", ascending = False)
# Out:
#            Neighborhood  \
# Id
# 78  Squirrel Hill South
# 69            Shadyside
# 77  Squirrel Hill North
# 14            Brookline
# 64         Point Breeze
# ..                  ...
# 31               Esplen
# 36           Glen Hazel
# 79            St. Clair
# 88             West End
# 5     Arlington Heights
#
#     Estimate; Aggregate household income in the past 12 months (in 2015 Inflation-adjusted dollars)  \
# Id
# 78                                        659886300.0
# 69                                        605635700.0
# 77                                        577467500.0
# 14                                        366945900.0
# 64                                        314958500.0
# ..                                                ...
# 31                                          5433900.0
# 36                                          4773300.0
# 79                                          3867600.0
# 88                                          3615800.0
# ...
